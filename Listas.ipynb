# %% [markdown]
# Listas de Produtos de uma loja:

# %%
produtos = ['Tv', 'celular', 'mouse', 'teclado', 'tablet']

# %% [markdown]
# Lista de Unidades Vendidas de cada produto da loja

# %%
vendas = [1000, 1500, 350, 300, 900]

# %%
print('Vendas do produto {} foram de {} unidades'.format(produtos[3], vendas[3]))
# Out:
# Vendas do produto teclado foram de 300 unidades

# %%
texto = 'lira@gmail.com'
print(texto[1])
# Out:
# i

# %% [markdown]
# Como descobrir o índice de um item de uma lista?

# %% [markdown]
# Digamos que você puxou do Banco de Dados da sua empresa uma lista com todos os produtos que a empresa vende e a quantidade em estoque de todos eles.

# %%
produtos = ['tv','celular','tablet','mouse','teclado','geladeira','forno']
estoque = [100,150,100,120,70,90,80,15]

# %% [markdown]
# Como faço pra descobrir a quantidade em estoque da geladeira?

# %%
i = produtos.index('geladeira')
print(i)

qtde_estoque = estoque[i]
print(f'Quantidade em estoque da geladeira é de {qtde_estoque}')
# Out:
# 5
# Quantidade em estoque da geladeira é de 90

# %% [markdown]
# Programa de consulta de estoque. Se digitar um nome que não exista, ele vai ser avisado. Caso exista, será mostrado a qtd em estoque

# %%
produto = input('Qual produto você procura?')
i = produtos.index(produto)

if produto in produtos:
    qtde_estoque = estoque[i]
    print('A quantidade em estoque de {} é de {}'.format(produto, qtde_estoque))
else:
    print('Esse produto não está disponível')
# Out:
# A quantidade em estoque de teclado é de 70

# %% [markdown]
# Adicionar e Remover itens de uma lista

# %%
apple = ['apple tv', 'mac', 'iphone x', 'ipad', 'apple watch', 'mac book', 'airpods']

#adicionar o iphone 11
apple.append('iphone 11')
print(apple)

#remover o iphone x
apple.remove('iphone x')
print(apple)

#outra forma de remover com o pop (armazena o valor em uma variável)
item_removido = apple.pop(1)
print(apple)

try:
    apple.remove('airpods')
    print(apple)
except:
    ('airpods não existe na lista de produtos')
# Out:
# ['apple tv', 'mac', 'iphone x', 'ipad', 'apple watch', 'mac book', 'airpods', 'iphone 11']
# ['apple tv', 'mac', 'ipad', 'apple watch', 'mac book', 'airpods', 'iphone 11']
# ['apple tv', 'ipad', 'apple watch', 'mac book', 'airpods', 'iphone 11']

# %% [markdown]
# Tamanho da Lista

# %%
tamannho = len(apple)
print('Temos {} produtos'.format(tamannho))
# Out:
# Temos 6 produtos

# %% [markdown]
# Maior e menor valor

# %%
mais_vendido = max(vendas)
menos_vendido = min(vendas)
print('O produto mais vendido teve {} unidades vendidas e o menos vendido teve {}'.format(mais_vendido, menos_vendido))
# Out:
# O produto mais vendido teve 1500 unidades vendidas e o menos vendido teve 300

# %% [markdown]
# Qual o nome do produto mais vendido e o menos vendido?

# %%
index = vendas.index(mais_vendido)
produto_mais_vendido = apple[index]

print(produto_mais_vendido)

i = vendas.index(menos_vendido)
produto_menos_vendido = apple[i]
print(produto_menos_vendido)
# Out:
# ipad
# mac book

# %% [markdown]
# Juntar listas
# 2 formas
# - Lista1.extend(lista2)
# - Lista_nova = lista1 + lista2

# %%
apple = ['apple tv', 'mac', 'iphone x', 'iphone 11', 'Ipad', 'apple watch', 'mac book', 'airpods']
novos_produtos = ['iphone 12', 'ioculos']

apple.extend(novos_produtos)
print(apple)

#todos_produtos = apple + novos_produtos
#print(todos_produtos)

apple.remove('ioculos')
apple.remove('iphone 12')
# Out:
# ['apple tv', 'mac', 'iphone x', 'iphone 11', 'Ipad', 'apple watch', 'mac book', 'airpods', 'iphone 12', 'ioculos']

# %% [markdown]
# Ordenar valores (Ordem alfabética, crescente, decrescente)
# - lista.sort
#
# Obs: Letras maiúsculas vem antes das minúsculas em Python

# %%
apple.sort()
print(apple)
# Out:
# ['Ipad', 'airpods', 'apple tv', 'apple watch', 'ioculos', 'iphone 11', 'iphone 12', 'iphone x', 'mac', 'mac book']

# %%
vendas.sort()
print(vendas)
# Out:
# [300, 350, 900, 1000, 1500]

# %%
#Ordem decrescente
vendas.sort(reverse=True)
print(vendas)
# Out:
# [1500, 1000, 900, 350, 300]

# %% [markdown]
# Print de Listas
# - print "normal"
# - método join -> delimitador.join(lista)

# %%
print(apple)

print('\n'.join(apple))
# Out:
# ['apple tv', 'mac', 'iphone x', 'iphone 11', 'Ipad', 'apple watch', 'mac book', 'airpods']
# apple tv
# mac
# iphone x
# iphone 11
# Ipad
# apple watch
# mac book
# airpods

# %% [markdown]
# As vezes, ao importar algo, as informações já vem como um texto único, mas separado por um delimitador como virgula, então usar o split() é uma boa opção!

# %%
produt_apple = 'apple tv, mac, iphone x, iphone 11, Ipad, apple watch, mac book, airpods'
lista = produt_apple.split(', ')

print(lista)
# Out:
# ['apple tv', 'mac', 'iphone x', 'iphone 11', 'Ipad', 'apple watch', 'mac book', 'airpods']

# %% [markdown]
# Alterações "Incrementais" de variáveis

# %%
lista = ['mac', 'iphone']
vendas = [100, 200]
#adicionando ipad na lista
#  lista.append('Ipad')
# OU
lista = lista + ['Ipad']
print(lista)

soma_vendas = 300
soma_vendas += 500 #vendas do Ipad
print(soma_vendas)

vendas = vendas + [500]

email = 'Esse mês vendemos um total de {} produtos, sendo:\n{} unidades de {}\n{} unidades de {}\n{} unidades de {}'.format(soma_vendas, vendas[0], lista[0], vendas[1], lista[1],vendas[2],lista[2])
print(email)
# Out:
# ['mac', 'iphone', 'Ipad']
# 800
# Esse mês vendemos um total de 800 produtos, sendo:
# 100 unidades de mac
# 200 unidades de iphone
# 500 unidades de Ipad

# %% [markdown]
# Exercícios

# %% [markdown]
# 1) Faturamento do Melhor e do Pior mês do Ano

# %%
meses = ['jan','fev','mar','abr','mai','jun','jul','ago','set','out','nov','dez']
vendas_1semestre = [25000, 29000, 22200, 17750, 15870, 19900]
vendas_2semestre = [19850, 20120, 17540, 15555, 49051, 9650]

vendas_do_ano = vendas_1semestre + vendas_2semestre
print(vendas_do_ano)

melhor_mes = max(vendas_do_ano)
print(melhor_mes)
pior_mes = min(vendas_do_ano)
print(pior_mes)
# Out:
# [25000, 29000, 22200, 17750, 15870, 19900, 19850, 20120, 17540, 15555, 49051, 9650]
# 49051
# 9650

# %% [markdown]
# 2) Relacione as duas listas, para dizer qual foi o nome do melhor e pior mês, e calcular o faturamento anual e quanto o melhor mês representa disso

# %%
i = vendas_do_ano.index(melhor_mes)
nome_melhormes = meses[i]

index = vendas_do_ano.index(pior_mes)
nome_piormes = meses[index]
print(i)
print(nome_melhormes)
print(nome_piormes)

print('O melhor mês do ano foi {} com {} vendas. E o pior mês do ano foi {} com {} vendas'.format(nome_melhormes, melhor_mes, nome_piormes, pior_mes))

faturamento_anual = sum(vendas_do_ano)
print('Faturamento Anual: R${:,}'.format(faturamento_anual))

#Quanto o melhor mês representa do total faturado no ano?
porcentagem_melhormes = (melhor_mes / faturamento_anual)
print('O melhor mês representa {:.2%} das vendas do ano todo.'.format(porcentagem_melhormes))

#Quanto o pior mês representa do total faturado no ano?
porcentagem_piormes = (pior_mes / faturamento_anual)
print('O pior mês representa {:.2%} das vendas do ano todo.'.format(porcentagem_piormes))
# Out:
# 10
# nov
# dez
# O melhor mês do ano foi nov com 49051 vendas. E o pior mês do ano foi dez com 9650 vendas
# Faturamento Anual: R$261,486
# O melhor mês representa 18.76% das vendas do ano todo.
# O pior mês representa 3.69% das vendas do ano todo.

# %% [markdown]
# 3) Criar uma lista com top 3 valores de vendas do ano

# %%
top3 = []
top3.append(melhor_mes)
vendas_do_ano.remove(melhor_mes)
top3.append(max(vendas_do_ano))
vendas_do_ano.remove(max(vendas_do_ano))
top3.append(max(vendas_do_ano))
vendas_do_ano.remove(max(vendas_do_ano))

print(top3)
# Out:
# [49051, 29000, 25000]

# %% [markdown]
# Copiar e "Igualdade" de Listas
# - lista2 = lista1.copy()
# - lista2 = lista1[:]

# %%
lista = ['ipad', 'iphone x', 'apple tv']
lista2 = lista.copy()

lista[1] = 'Iphone 11'
print(lista)
print(lista2)

#assim, você cria uma cópia e vai ter duas listas diferentes pra trabalhar. senão, se fizer:
#lista2 = lista1 (tudo o que você mudar na lista1 vai afetar a 2, o que pode não ser ideal em alguns casos)
# Out:
# ['ipad', 'Iphone 11', 'apple tv']
# ['ipad', 'iphone x', 'apple tv']

# %% [markdown]
# Listas de listas (nested list)
#
# - É quando cada item dentro de uma lista, também é uma outra lista separada

# %%
vendedores = ['Lira', 'João', 'Diego', 'Alon']
produtos = ['ipad', 'iphone']
vendas = [
     [100, 200],
     [300, 500],
     [50, 1000],
     [900, 10],
]

# %% [markdown]
# - Quanto João vendeu de Ipad?
# - Quanto Diego vendeu de iPhone?
# - Qual o total de vendas de iPhone?

# %%
vendas_ipad_joao = vendas[1][0] #2° item da lista, indice 1
print(vendas_ipad_joao)

vendas_iphone_diego = vendas[2][1]
print(vendas_iphone_diego)

totalvendas_iphone = vendas[0][1] + vendas[1][1] + vendas [2][1] + vendas [3][1]
print(totalvendas_iphone)
# Out:
# 300
# 1000
# 1710

# %% [markdown]
# E se o Lira na verdade fez 50 vendas de iphone?

# %%
vendas[0][1] = 50
print(vendas)
# Out:
# [[100, 50], [300, 500], [50, 1000], [900, 10]]

# %% [markdown]
# Temos um novo produto, "mac", vamos adicionar as vendas de cada um dos vendedores

# %%
vendas_mac = [10, 15, 6, 70]

vendas[0].append(vendas_mac[0])
vendas[1].append(vendas_mac[1])
vendas[2].append(vendas_mac[2])
vendas[3].append(vendas_mac[3])

print(vendas)
# Out:
# [[100, 50, 10], [300, 500, 15], [50, 1000, 6], [900, 10, 70]]

# %% [markdown]
# Mudança na carga tributária
# - 10% de imposto no livro
# Ex: Se eu fosse vender um livro por 100, teria que vendê-lo por 110

# %%
produtos = ['computador', 'livro', 'tablet', 'celular', 'tv', 'ar condicionado', 'alexa', 'máquina de café', 'kindle']

#cada item da lista dos produtos corresponde a quantidade de vendas no mês e preço, nessa ordem
produtos_ecommerce = [
    [10000, 2500],
    [50000, 40],
    [7000, 1200],
    [20000, 1500],
    [5800, 1300],
    [7200, 2500],
    [200, 800],
    [3300, 700],
    [1900, 400]
]


if 'livro' in produtos:
    i = produtos.index('livro')
    total_antigo = produtos_ecommerce[i][0] * produtos_ecommerce[i][1] #Quantidade * preço

    produtos_ecommerce[i][1] = produtos_ecommerce[i][1] * 1.1

    novo_total = produtos_ecommerce[i][0] * produtos_ecommerce[i][1] #Quantidade * preço novo com imposto
    print(produtos_ecommerce[i])
    print('Vamos pagar de imposto a mais: R${:,}'.format(novo_total - total_antigo))
# Out:
# 2,200,000
# [50000, 44.0]
# Vamos pagar de imposto a mais: R$200,000.0

# %% [markdown]
# ### Exercício Final 1/4
# ### Crie um sistema de cadastro de produtos em uma lista de produtos
# Seu sistema deve:
# - Pegar o usuário qual produto vai ser cadastrado por meio de um input
# - Garantir que se o usuário escrever com letra maiúscula ou minúscula, o produto continua sendo o mesmo produto
# - Se o usuário inserir um produto que já existe na lista, o programa deve printar a mensagem "Produto já existente, tente novamente"
# - Se o usuário inserir um produto que não existe na lista, o programa deve inserir na lista, printar a mensagem Produto X cadastrado com sucesso e em seguida printar a lista completa

# %%
produtos = ["celular", "camera", "fone de ouvido", "monitor"]

cadastrar = input('Qual produto você vai cadastrar?')
cadastrar = cadastrar.lower()

if cadastrar in produtos:
    print('Produto já existente, tente novamente')
else:
    produtos.append(cadastrar)
    print('Produto {} cadastrado com sucesso'.format(cadastrar))
    print(produtos)

# %% [markdown]
# ### Exercício Final 2/4
# #### Crie um sistema de consulta de preços
# Seu sistema deve:
# - Pedir para o usuário o nome de um produto
# - Caso o produto exista na lista de produtos, o programa deve retornar o preço do produto como resposta
#        - Ex: O produto celular custa R$1500
# - Caso o produto não exista na lista de produtos, o programa deve printar uma mensagem para o usuário tentar novamente

# %%
produtos = ["celular", "camera", "fone de ouvido", "monitor"]
precos = [1500, 1000, 800, 2000]

nomeproduto = input('Digite o nome de um produto a verificar')
nomeproduto = nomeproduto.lower()

if nomeproduto in produtos:
    i = produtos.index(nomeproduto)
    preco_produto = precos[i]
    print(f'O produto {nomeproduto} custa R${preco_produto}')
else:
    print('Esse produto não existe, tente novamente')

# %% [markdown]
# ### Exercício Final 3/4
# #### Crie um sistema de consulta de bônus dos funcionários
# Seu sistema deve:
# - Pegar o valor de vendas do funcinoário por meio de um input
# - Calcular o bônus do funcionário de acordo com a seguinte regra:
#       - Se o funcionário vendeu mais de 1000 unidades, ele ganha R$2 de bonus para cada unidade vendida
#       - Se o funcionário vendeu mais de 5000 unidades, ele ganha R$2 de bônus para cada unidade + um valor fixo de R$1000
#       - Se o funcionário vendeu menos de 1000 unidades, ele não ganha bônus
# - Printar no final o valor do bônus do funcionário

# %%
vendas_funcionario = float(input('Quantas vendas foram feitas?'))

if vendas_funcionario >= 5000:
    bonus = 2 * vendas_funcionario  + 1000
elif vendas_funcionario >= 1000:
    bonus = 2 * vendas_funcionario
else:
    bonus = 0
print('O seu bônus foi de R${:,}, por ter efetuado {} vendas'.format(bonus, vendas_funcionario))

# %% [markdown]
# ### Exercício Final 4/4
# Crie um programa que consiga descobrir qual dos vendedores vendeu mais
# <br>As vendas dos vendedores são listas com a quantidade vendida por cada vendedor

# %%
vendas = [
    [10, 20, 100, 80, 90, 100, 20, 30, 44, 55, 33, 34, 100, 90, 80, 39, 87, 45, 50, 50, 50, 50, 40, 30, 3, 93, 39, 49, 88],    
    [100, 1, 1, 4, 5, 90, 100, 20, 4, 5, 100, 100, 100, 100, 100, 93, 20, 15, 40, 90, 90, 90, 90, 90, 90, 33, 22, 44, 43, 34],
]

vendedor1 = sum(vendas[0])
vendedor2 = sum(vendas[1])

if vendedor1 > vendedor2:
    print('O vendedor 1 vendeu mais que o 2')
else:
    print('O vendedor 2 vendeu mais que o 1')
